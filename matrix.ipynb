# %% [markdown]
# <a href="https://colab.research.google.com/github/divyar2674/data-handling-and-visualization/blob/main/matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2-d heatmap
import numpy as np
import matplotlib.pyplot as plt
data=np.random.random((13,16))
plt.imshow(data,cmap="viridis")
plt.title('2-D heat map')
plt.colorbar()
plt.show()

# %%
#seaborn
import seaborn as a
data=np.random.randint(low=14,high=100,size=(10,10))
hm=a.heatmap(data=data,annot=True)
plt.show()
